# %% [markdown]
# <a href="https://colab.research.google.com/github/deepakkush02/Airbnb_Visualsation/blob/main/Deepak_kushwaha_%7C_Airbnb_Visualsation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Capstone Project: Data Visualization Tools

# %% [markdown]
# NAME : DEEPAK KUSHWAHA
#
# Github link: [Github link](https://)
#
# Dataset Name: Airbnb Listings Data
#
# Source: [Link to dataset](http://insideairbnb.com/get-the-data/)
#
# Cities: Chicago & New Orleans

# %% [markdown]
# **Dataset Selection:**
#
# For this EDA project, we have chosen the "Airbnb Listings Data" dataset from 2 major cities: Chicago and New Orleans. This dataset provides a comprehensive snapshot of various attributes related to Airbnb listings, such as property type, neighbourhood, pricing, availability, and more.

# %% [markdown]
# **Why Airbnb:**
#
# Airbnb, a prominent online platform, enables individuals to reserve accommodations spanning a spectrum from beds and rooms to apartments and entire homes across global locales. This user-centric platform serves as a conduit for seamless property rentals, negating the need for intricate intermediaries or substantial capital outlays. Notably, users can secure lodgings at significantly competitive rates relative to traditional hotels. Distinctively, Airbnb extends its reach to regions where convectional hotel presence might be limited, offering an avenue for lodging acquisition in underserved locales. Moreover, the inclination towards immersive local experiences often steers individuals towards selecting accommodations embedded within native communities, fostering a distinctive preference for authenticity and cultural engagement.

# %% [markdown]
# Description: The Airbnb Listings Data contains information about different properties available for rent on Airbnb in a specific city. Each record represents a unique listing and includes attributes such as property type, neighbourhood, number of bedrooms, pricing, availability, host information, and more.
#
# **Key Attributes**:
#
# 1. id: Unique identifier for each listing.
#
# 2. name: The title or name of the listing.
#
# 3. host_id: Unique identifier for the host of the property.
#
# 4. host_name: Name of the host.
#
# 5. neighbourhood_group: The broader area or group that the neighbourhood belongs to.
#
# 6. neighbourhood: Specific neighbourhood where the property is located.
#
# 7. latitude: Latitude coordinate of the property.
#
# 8. longitude: Longitude coordinate of the property.
#
# 9. room_type: Type of room (e.g., Private room, Entire home/apt, Shared room).
#
# 10. price: Price of the listing per night.
#
# 11. minimum_nights: Minimum number of nights required for booking.
#
# 12. number_of_reviews: Total number of reviews received for the listing.
#
# 13. last_review: Date of the last review.
#
# 14. reviews_per_month: Average number of reviews per month.
#
# 15. availability_365: Number of days the listing is available for booking in a year.

# %% [markdown]
# #### Link of Datasets -
# Chicago: [Chicago](https://drive.google.com/file/d/1kOtxd-4g1GPZ0mcxkL4IvV7cHr7LrHTx/view?usp=sharing)
#
# New_Orlense: [New_Orlense](https://drive.google.com/file/d/1oFJ1I7a01-g5YduvA1PMrjbW9r2AMaUj/view?usp=sharing)

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Chicago_df = pd.read_csv('/content/drive/MyDrive/airbnb data/Chicago listings.csv.csv')
New_Orleans_df = pd.read_csv('/content/drive/MyDrive/airbnb data/New Orleans listings.csv.csv')

# %%
Chicago_df.head(1)
# Out:
#      id                                               name  host_id host_name  \
# 0  2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...     2613   Rebecca
#
#    neighbourhood_group neighbourhood  latitude  longitude     room_type  \
# 0                  NaN     Hyde Park   41.7879   -87.5878  Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    129               3                220  2023-06-10               2.14
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               1               350                     19
#
#   license
# 0     NaN

# %%
Chicago_df[['name', 'Rating', 'No_of_bedroom', 'No_of_bed','No_of_bath']] = Chicago_df['name'].str.split(' · ' , expand = True)
Chicago_df.head(1)
# Out:
#      id              name  host_id host_name  neighbourhood_group  \
# 0  2384  Condo in Chicago     2613   Rebecca                  NaN
#
#   neighbourhood  latitude  longitude     room_type  price  ...  last_review  \
# 0     Hyde Park   41.7879   -87.5878  Private room    129  ...   2023-06-10
#
#    reviews_per_month calculated_host_listings_count  availability_365  \
# 0               2.14                              1               350
#
#    number_of_reviews_ltm  license  Rating No_of_bedroom No_of_bed  \
# 0                     19      NaN   ★4.99     1 bedroom     1 bed
#
#       No_of_bath
# 0  1 shared bath
#
# [1 rows x 22 columns]

# %%
Chicago_df = Chicago_df.drop('neighbourhood_group', axis=1)

# %%
Chicago_df['Rating'] = Chicago_df['Rating'].str.replace('★', '')

# %%
Chicago_df = Chicago_df.dropna(subset=['No_of_bath'])

# %%
Chicago_df.head(1)
# Out:
#      id              name  host_id host_name neighbourhood  latitude  \
# 0  2384  Condo in Chicago     2613   Rebecca     Hyde Park   41.7879
#
#    longitude     room_type  price  minimum_nights  ...  last_review  \
# 0   -87.5878  Private room    129               3  ...   2023-06-10
#
#   reviews_per_month  calculated_host_listings_count  availability_365  \
# 0              2.14                               1               350
#
#    number_of_reviews_ltm  license Rating No_of_bedroom No_of_bed  \
# 0                     19      NaN   4.99     1 bedroom     1 bed
#
#       No_of_bath
# 0  1 shared bath
#
# [1 rows x 21 columns]

# %%
print("Chicago",(Chicago_df.isnull()).sum())
# Out:
# Chicago id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                        419
# reviews_per_month                  419
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           1291
# Rating                               0
# No_of_bedroom                        0
# No_of_bed                            0
# No_of_bath                           0
# dtype: int64

# %%
Chicago_df.to_csv('Cleaned_Chicago.csv', index=False)

# %%
New_Orleans_df.head(1)
# Out:
#       id                                               name  host_id  \
# 0  19091  Rental unit in New Orleans · ★4.89 · 1 bedroom...    72880
#
#   host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0      John                  NaN      Leonidas    29.961   -90.1195
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt     60               1                496  2022-04-04
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                3.1                               1                10
#
#    number_of_reviews_ltm                       license
# 0                      0  22-RSTR-14107, 22-OSTR-14105

# %%
New_Orleans_df[['name', 'Rating', 'No_of_bedroom', 'No_of_bed','No_of_bath']] = New_Orleans_df['name'].str.split(' · ' , expand = True)

# %%
New_Orleans_df = New_Orleans_df.drop('neighbourhood_group', axis=1)
New_Orleans_df['Rating'] = New_Orleans_df['Rating'].str.replace('★', '')
New_Orleans_df = New_Orleans_df.dropna(subset=['No_of_bath'])

# %%
New_Orleans_df.head(1)
# Out:
#       id                        name  host_id host_name neighbourhood  \
# 0  19091  Rental unit in New Orleans    72880      John      Leonidas
#
#    latitude  longitude        room_type  price  minimum_nights  ...  \
# 0    29.961   -90.1195  Entire home/apt     60               1  ...
#
#    last_review reviews_per_month  calculated_host_listings_count  \
# 0   2022-04-04               3.1                               1
#
#    availability_365  number_of_reviews_ltm                       license  \
# 0                10                      0  22-RSTR-14107, 22-OSTR-14105
#
#   Rating No_of_bedroom No_of_bed No_of_bath
# 0   4.89     1 bedroom     1 bed     1 bath
#
# [1 rows x 21 columns]

# %%
print("Chicago",(New_Orleans_df.isnull()).sum())

# %%
New_Orleans_df.to_csv('Cleaned_New_Orleans.csv',index = False)

# %% [markdown]
# # After Cleaning Dataset Link -
# Chicago: [Cleaned_Chicago](https://drive.google.com/file/d/1qh8oR_jngOk8Vt3uR0JF1Hbv5f9osEWH/view?usp=drive_link)
#
# New_Orleanse: [Cleaned_New_Orleanse](https://drive.google.com/file/d/1Nmz6cZndVEQbz_Ym-hBKheJhhxZKZSbz/view?usp=drive_link)

# %% [markdown]
# # Transforming EDA Projects to Dashboards

# %% [markdown]
# ### The dataset on which EDA was performed for the capstone project has been used to create a visual Tableau dashboard.

# %% [markdown]
# **Problem Statement:**
#
# In the context of Airbnb operations, how can the utilisation of Tableau facilitate a comprehensive comparative examination between Chicago and New Orleans, two diverse urban environments?
#
# This inquiry seeks to leverage Tableau's visual analytics capabilities to uncover and illustrate the shared attributes, disparities, and distinctive patterns inherent to Airbnb's presence in these cities, thus elevating the depth and insightfulness of the study.

# %% [markdown]
# # Chicago  Dashboard

# %% [markdown]
# ### Link of Chicago_Dashboard**
#
# Dashboard: [Chicago_Dashboard](https://drive.google.com/file/d/1IAthi1Xpp0GSc6-EYUDppwcAX8Cxc8zr/view?usp=sharing)

# %% [markdown]
# ### Divide the visualisation findings into 4 categories:
#
# - Overview of Airbnb
# - Property analysis
# - Pricing analysis
# - Host analysis

# %% [markdown]
# ###Neighborhood Insights: Popular Areas, Average Prices, and Listings
#
# In our Airbnb dashboard, we can quickly identify the popular neighborhoods by analyzing the booking data. By displaying the average prices and the number of listings in each neighborhood, users can easily spot the most sought-after areas for accommodations, helping them make informed booking decisions. This feature allows guests to understand pricing trends and the availability of listings in specific neighborhoods, enhancing their overall Airbnb experience.

# %% [markdown]
# ##Chicago_Overview of Airbnb
#
# ![New_Orleans_Overview of Airbnb.png](data:image/png;base64,...)

# %% [markdown]
# ###Property and Room Type Distribution: Insights into Airbnb's Offerings
#
# The Airbnb dashboard showcases the distribution of property types and room types. It reveals the percentage breakdown of property types, such as houses, apartments, and more, allowing users to see the most prevalent options. Similarly, it displays the proportion of room types, including entire homes, private rooms, and shared spaces, providing valuable insights for users to make informed booking decisions.

# %% [markdown]
# ##Chicago_Property Analysis
#
# ![New_Orleans_Property Analysis.png](data:image/png;base64,...)

# %% [markdown]
# ###Pricing Trends and Host Insights: Unveiling the Airbnb Dashboard
#
# The Airbnb dashboard displays a dynamic pricing analysis that visually illustrates how rates fluctuate across different locations and property types based on reviews. Additionally, it highlights correlations between host characteristics, such as host type, and key factors like reviews and pricing, offering valuable insights for hosts and travelers alike.

# %% [markdown]
# ## Chicago_ Pricing Analysis And Host Analysis
#
# ![New_Orleans_ Pricing Analysis And Host Analysis.png](data:image/png;base64,...)

# %% [markdown]
# # New_Orleanse Dashboard

# %% [markdown]
# #### Link of New_Orleans Dashboard
# Dashboard: [New_Orleans](https://drive.google.com/file/d/1fprGoIm_03LvOt_sSA92oMsid8NbuwP5/view?usp=sharing)

# %% [markdown]
# ## New_Orleans_Overview of Airbnb
#
# ![New_Orleans_Overview of Airbnb.png](data:image/png;base64,...)

# %% [markdown]
# ## New_Orleans_Property Analysis
#
# ![New_Orleans_Property Analysis.png](data:image/png;base64,...)

# %% [markdown]
# ## New_Orleans_ Pricing Analysis And Host Analysis
#
# ![New_Orleans_ Pricing Analysis And Host Analysis.png](data:image/png;base64,...)

# %% [markdown]
# # Thank You
